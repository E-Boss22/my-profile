# %% [markdown]
# # 🔍 A Night at the Museum — Assessment | Version C
# ### Algorithmic Thinking & Programming Structures — Final Session
#
# ---

# %%
# ============================================================
#  STUDENT INFORMATION — Fill in before you start
# ============================================================
student_1 = ""   # First name + Last name of student 1
student_2 = ""   # First name + Last name of student 2
group     = ""   # Your group (e.g. "Group A")

print(f"Assessment started — {student_1} & {student_2} | {group}")

# %% [markdown]
# ---
# ## 🏛️ The Story
#
# > *It is Monday morning. You arrive at the **Museum of Modern Art** and find the director, **Mr. Fontaine**, in a state of panic.*
# >
# > *"It's gone," he whispers. "**The Golden Algorithm** — our most precious painting, estimated at **€2,000,000** — was stolen last night. The police are on their way, but we need answers NOW."*
# >
# > *Five people were present at the museum last night. One of them is the thief.*
# >
# > *The director hands you a USB drive. "Everything is in there — security logs, witness reports, access records. Find the culprit."*
#
# ---

# %% [markdown]
# ## 🕵️ The Suspects
#
# | Name | Role | Notes |
# |---|---|---|
# | **Clara Voss** | Art Restorer | Worked on the painting last week |
# | **Nathan Blake** | Gallery Owner | Knows all potential buyers |
# | **Iris Fontaine** | Journalist | Covered the museum opening |
# | **René Moreau** | Security Guard | Knows the camera blind spots |
# | **Selma Aït** | Insurance Expert | Assessed the painting one month ago |
#
# ---

# %% [markdown]
# ## 📋 Rules
#
# - This notebook contains **4 investigation blocks** + **1 bonus block** + **2 reflection questions**
# - Each block gives you a **clue** (`CLUE_1`, `CLUE_2`...) — note them in the dashboard below
# - **Do not move to the next block** until you have the correct result
# - Work **in pairs** — discuss before you write
# - **No AI, no internet, no communication between groups**
#
# > ⚠️ You are working on **Version C**. Results copied from another group will produce a wrong final verdict.
#
# ---
# ### 🗂️ Dashboard — note your clues here as you go
#
# ```
# CLUE_1 = ___    (Block 1)
# CLUE_2 = ___    (Block 2)
# CLUE_3 = ___    (Block 3)
# CLUE_4 = ___    (Block 4)
# ```
#
# ---

# %% [markdown]
# ---
# ## 🔎 Block 1 — The Visitor Log
# ### Concepts: Lists, `for` loop, `len()`
#
# > *You open the USB drive and find the museum's entry register: the list of everyone present last night.*
# >
# > *A witness gave you a key piece of information: "The thief had a badge with their full name — first name and last name. Short names on the register cannot be them."*
# >
# > *You decide to keep only names with **more than 8 characters** — long enough to contain both a first and last name.*
#
# **Your mission:**
# 1. Calculate the total number of people present last night
# 2. Using a `for` loop, extract only the names whose length is **strictly greater than 8 characters**
# 3. Store these names in a new list called `long_names`
# 4. Display `long_names` and its length
# 5. Store **the number of names** in `CLUE_1` (not the list — just the number!)
#
# > ⚠️ `CLUE_1` will be essential in the Bonus Block!

# %%
# Museum entry register — everyone present last night
# ⚠️ This version of the notebook (Version C) contains the name: Leo Faure
all_present = [
    "Clara Voss",
    "Nathan Blake",
    "Iris Fontaine",
    "René Moreau",
    "Selma Aït",
    "Paul Kim",
    "Kay Cox",
    "Jay Finn",
    "Leo Faure",
    "Tom Reed",
    "Li Wei",
    "Ben Fox",
]

# 1. Total number of people present
# Your code here:


# 2 & 3. Names longer than 8 characters → long_names
long_names = []
# Your code here:


# 4. Display long_names and its length
# Your code here:


# 5. Store THE NUMBER of names (not the list!) in CLUE_1
CLUE_1 = None  # Replace None with the number of names in long_names
print("CLUE_1 =", CLUE_1)

# %% [markdown]
# > 📋 **Don't forget!** Note `CLUE_1` in your dashboard at the top of the notebook.

# %% [markdown]
# ---
# ## 🕐 Block 2 — The Security Logs
# ### Concepts: Variables, arithmetic, conditions, `range(len(...))`
#
# > *You then find the security logs: for each suspect, the system recorded their entry and exit time.*
# >
# > *Times are whole hours, without minutes (for example: 18 means 6:00 PM, 21 means 9:00 PM).*
# >
# > *According to the cameras, the painting disappeared between **9:00 PM and 11:00 PM** (21 and 23). Only someone who entered before 9:00 PM and left after 11:00 PM could have committed the theft.*
#
# **Your mission:**
# 1. For each suspect, calculate their time of presence (exit time - entry time)
# 2. Identify suspects present during the crime window: entry ≤ 21 **AND** exit ≥ 23
# 3. Find the suspect who stayed the **longest** overall
# 4. Store the **number of letters in their first name** in `CLUE_2`
#
# > ⚠️ Use `.split()[0]` to extract the first name from the full name.

# %%
suspects    = ["Clara Voss", "Nathan Blake", "Iris Fontaine", "René Moreau", "Selma Aït"]
entry_times = [20, 18, 21, 19, 16]   # entry times (whole hours, e.g. 18 = 6:00 PM)
exit_times  = [22, 21, 23, 22, 23]   # exit times  (whole hours, e.g. 21 = 9:00 PM)

# 1 & 2. Loop with range(len(...)), calculate duration,
#        display those present during the crime window (entry ≤ 21 AND exit ≥ 23)
print("--- Suspects present during the theft ---")
# Your code here:


# 3. Find the suspect who stayed the longest
max_duration    = 0
longest_suspect = ""
# Your code here:


print("Suspect who stayed the longest:", longest_suspect)

# 4. Number of letters in their first name
CLUE_2 = None  # Replace None with your result
print("CLUE_2 =", CLUE_2)

# %% [markdown]
# > 📋 **Don't forget!** Note `CLUE_2` in your dashboard at the top of the notebook.

# %% [markdown]
# ---
# ## 🐛 Block 3 — The Corrupted Report
# ### Concepts: Debugging (3 bugs to fix)
#
# > *Among the files on the USB drive, you find a program written by the night guard, René Moreau. He tried to record his testimony as Python code — but he is not a programmer, and his code contains **3 errors**.*
# >
# > *He remembers seeing several suspects near the EAST wing. He wanted to display only those whose **full name is more than 8 characters long** — because in his view, only people with a full name (first and last) were worth reporting.*
# >
# > *Fix his errors to read his complete testimony.*
#
# **Your mission:**
# 1. Read the buggy code below **carefully, without running it**
# 2. Identify the **3 bugs** and apply all corrections in the correction cell below
# 3. Run your corrected code and check the output
# 4. Look at the value of the `location` variable in your corrected code — this is your `CLUE_3`. Assign it: `CLUE_3 = "EAST"`
# 5. Explain each bug in the Markdown cell below
#
# > 💡 Possible bug types: **syntax error** (Python refuses to run) / **logic error** (Python runs but the result is wrong) / **type error** (Python cannot perform the operation)
#
# > ⚠️ **Do not run the cell below** — it contains intentional errors. Copy it into the correction cell and fix it there.

# %% [markdown]
# ```python
# # ⚠️ BUGGY CODE — READ ONLY, DO NOT RUN
# # Copy this into the correction cell below and fix the 3 bugs
#
# witness_name = "Moreau"
# witness_age  = 47
# crime_hour   = "21"
#
# print("=== GUARD'S TESTIMONY ==="
#
# suspects_seen = ["Iris Fontaine", "Nathan Blake", "Selma Aït"]
# location = "EAST"
#
# for suspect in suspects_seen:
#     if len(suspect) > 15:
#         print("I saw", suspect, "near the", location, "wing")
#
# total_time = crime_hour + 2
# print("Incident occurred around hour:", total_time)
# print("Location clue: EAST WING")
# ```

# %%
# ✅ YOUR CORRECTED CODE HERE
# Copy the buggy code from above and fix the 3 bugs


# Once your code runs correctly, assign CLUE_3:
# Look at the value of the variable 'location' in your code above.
# CLUE_3 must be exactly that value (as a string, in quotes).
CLUE_3 = None  # Replace None with the value of 'location' — e.g. CLUE_3 = "EAST"
print("CLUE_3 =", CLUE_3)

# %% [markdown]
# #### 🔍 Bug explanation
# *For each bug, explain in one sentence what was wrong and what you changed.*
#
# **Bug 1:**
# > *(your explanation here)*
#
# **Bug 2:**
# > *(your explanation here)*
#
# **Bug 3:**
# > *(your explanation here)*

# %% [markdown]
# > 📋 **Don't forget!** Note `CLUE_3` in your dashboard at the top of the notebook.

# %% [markdown]
# ---
# ## 🧪 Block 4 — The Suspect Profile
# ### Concepts: Functions, conditions, loops
#
# > *By cross-referencing the data on the USB drive, you build the thief's profile. To have stolen the painting, three conditions had to be met:*
# >
# > *1. Possess an **access badge** to the storage rooms (only certain people had one)*
# > *2. Have been **present in the museum** that night*
# > *3. Have **no verified alibi** for the night of the theft*
#
# **Your mission:**
# 1. Define a function `check_suspect(name, has_badge, was_present, has_alibi)`
# 2. It returns `True` if `has_badge == True` **AND** `was_present == True` **AND** `has_alibi == False`
# 3. Otherwise it returns `False`
# 4. Apply it to each suspect using a loop
# 5. Display and store the culprit's name in `CLUE_4`

# %%
suspect_names    = ["Clara Voss", "Nathan Blake", "Iris Fontaine", "René Moreau", "Selma Aït"]
has_badge_list   = [False, True, True, False, False]  # access badge to storage rooms
was_present_list = [True, True, False, True, True]  # present that night
has_alibi_list   = [True, False, True, True, True]  # verified alibi

# 1, 2 & 3. Define check_suspect
# Your code here:



# 4 & 5. Apply to each suspect and display the culprit
print("--- Suspect analysis ---")
# Your code here:



CLUE_4 = None  # Replace None with the culprit's name (in quotes)
print("CLUE_4 =", CLUE_4)

# %% [markdown]
# > 📋 **Don't forget!** Note `CLUE_4` in your dashboard at the top of the notebook.

# %% [markdown]
# ---
# ---
# ## 🏆 Bonus Block — The Coded Message
# ### Concepts: Strings, indexing, `for` loop
#
# > *Case solved — but while searching the guard's booth, you find one last mysterious file on the USB drive.*
# >
# > *It contains a message that looks like gibberish. But next to it, a handwritten note reads:*
# >
# > *"The truth hides at even positions. Read every other letter starting from the first one (index 0)."*
#
# **Your mission:**
# 1. Go through the message character by character using a `for` loop and `range(len(...))`
# 2. Extract only the characters whose index is **even** (0, 2, 4...)
# 3. Assemble them into a variable `decoded_message`
# 4. Display the decoded message
#
# > 💡 Reminder: an index is even if `i % 2 == 0`

# %%
message = "IB FdGiJdKnM\'OtP RsUtVeYaZlB FtGhJeK MpOaPiRnUtViYnZgB"

decoded_message = ""

# Your code here:


print("Decoded message:", decoded_message)

# %% [markdown]
# ---
# ---
# # 📝 Reflection Questions
#
# > *Answer in English directly in the Markdown cells below. One or two sentences per answer — be precise and concise.*
#
# ---
# ### Question 1 — About Block 2
#
# In Block 2, you used `range(len(suspects))` rather than `for suspect in suspects`.
#
# **Explain in one sentence why `range(len(...))` was necessary in this specific block.**
#
# > *Your answer here:*
#
# ---
# ### Question 2 — About Block 3
#
# You corrected three different types of bugs.
#
# **Which of the three bugs was the most dangerous, and why?**
#
# > 💡 Think about what Python tells you — or does *not* tell you — for each type of error.
#
# > *Your answer here:*

# %% [markdown]
# ---
# ---
# # ✅ Submission
#
# Before submitting, make sure you have:
#
# - [ ] Filled in your names and group at the top of the notebook
# - [ ] Run all cells in order with no unresolved errors
# - [ ] Noted the 4 clues in the dashboard
# - [ ] Explained the 3 bugs in Block 3
# - [ ] Answered the 2 Reflection Questions
#
# **To submit:** File → Download → Download .ipynb — then upload to the course platform.
#
# ---
# *A Night at the Museum — Version C — Algorithmic Thinking & Programming Structures*
